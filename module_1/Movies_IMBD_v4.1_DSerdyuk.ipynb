# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
data = pd.read_csv('movie_bd_v5.csv')
data.sample(5)
# Out:
#         imdb_id    budget    revenue  \
# 1653  tt0338325  20000000   16605763
# 661   tt0481536  12000000   43493123
# 1145  tt0301470  17000000   63102666
# 1781  tt0841046  35000000   18317151
# 197   tt2369135  66000000  203277636
#
#                                  original_title  \
# 1653                                  Paparazzi
# 661   Harold & Kumar Escape from Guantanamo Bay
# 1145                         Jeepers Creepers 2
# 1781             Walk Hard: The Dewey Cox Story
# 197                              Need for Speed
#
#                                                    cast  \
# 1653  Cole Hauser|Robin Tunney|Dennis Farina|Daniel ...
# 661   John Cho|Kal Penn|Neil Patrick Harris|Rob Cord...
# 1145  Ray Wise|Jonathan Breck|Garikayi Mutambirwa|Er...
# 1781  John C. Reilly|Jenna Fischer|Tim Meadows|Krist...
# 197   Aaron Paul|Dominic Cooper|Imogen Poots|Rami Ma...
#
#                             director  \
# 1653                    Paul Abascal
# 661   Jon Hurwitz|Hayden Schlossberg
# 1145                    Victor Salva
# 1781                     Jake Kasdan
# 197                      Scott Waugh
#
#                                                 tagline  \
# 1653                    One good shot deserves another.
# 661           This time they're running from the joint.
# 1145                            He can taste your fear.
# 1781  Life made him tough. Love made him strong. Mus...
# 197                For honor. For love. For redemption.
#
#                                                overview  runtime  \
# 1653  A rising Hollywood actor decides to take perso...       84
# 661   Having satisfied their urge for White Castle, ...      107
# 1145  After 23 horrifying days of gorging on human f...      104
# 1781  Singer Dewey Cox overcomes adversity to become...       96
# 197   The film revolves around a local street-racer ...      130
#
#                            genres  \
# 1653        Action|Drama|Thriller
# 661              Comedy|Adventure
# 1145              Horror|Thriller
# 1781                 Comedy|Music
# 197   Action|Crime|Drama|Thriller
#
#                                    production_companies release_date  \
# 1653                                   20th Century Fox     9/3/2004
# 661                                     New Line Cinema    4/25/2008
# 1145  United Artists|American Zoetrope|Myriad Pictur...     8/8/2003
# 1781   Columbia Pictures Corporation|Apatow Productions   12/21/2007
# 197   DreamWorks SKG|Reliance Entertainment|Bandito ...    3/13/2014
#
#       vote_average  release_year
# 1653           5.9          2004
# 661            6.0          2008
# 1145           5.4          2003
# 1781           6.5          2007
# 197            6.2          2014

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1889 entries, 0 to 1888
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   imdb_id               1889 non-null   object
#  1   budget                1889 non-null   int64
#  2   revenue               1889 non-null   int64
#  3   original_title        1889 non-null   object
#  4   cast                  1889 non-null   object
#  5   director              1889 non-null   object
#  6   tagline               1889 non-null   object
#  7   overview              1889 non-null   object
#  8   runtime               1889 non-null   int64
#  9   genres                1889 non-null   object
#  10  production_companies  1889 non-null   object
#  11  release_date          1889 non-null   object
#  12  vote_average          1889 non-null   float64
#  13  release_year          1889 non-null   int64
# dtypes: float64(1), int64(4), object(9)
# memory usage: 206.7+ KB

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# profit = revenue - budget was added, as not given in the original dataset
data['profit'] = data.revenue - data.budget 

#Possible way to split the date pf release
data[['month','day','year']] = data.release_date.str.split('/', expand=True) 

# Another way with type datetime
data['timefunc']= pd.to_datetime(data.release_date)

# required for 24th question: length of title:
data['title_length'] = data['original_title'].map(lambda x: len(x))

#created additional clolumn: number of words in tagline
data['num_words'] = data['overview'].map(lambda x: len(x.split(' '))) 

#function to split to the list with separatior '|'
def func(column):
    return str(column).split('|')

#function to combinate artists pairs:
import itertools as it
def func_comb(column):
    return list(it.combinations(column,2))

data.head()
# Out:
#      imdb_id     budget     revenue                original_title  \
# 0  tt0369610  150000000  1513528810                Jurassic World
# 1  tt1392190  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446  110000000   295238201                     Insurgent
# 3  tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# 0              The park is open.
# 1             What a Lovely Day.
# 2     One Choice Can Destroy You
# 3  Every generation has a story.
# 4            Vengeance Hits Home
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
# 3  Thirty years after defeating the Galactic Empi...      136
# 4  Deckard Shaw seeks revenge against Dominic Tor...      137
#
#                                       genres  ... release_date vote_average  \
# 0  Action|Adventure|Science Fiction|Thriller  ...     6/9/2015          6.5
# 1  Action|Adventure|Science Fiction|Thriller  ...    5/13/2015          7.1
# 2         Adventure|Science Fiction|Thriller  ...    3/18/2015          6.3
# 3   Action|Adventure|Science Fiction|Fantasy  ...   12/15/2015          7.5
# 4                      Action|Crime|Thriller  ...     4/1/2015          7.3
#
#    release_year      profit  month day  year   timefunc title_length  \
# 0          2015  1363528810      6   9  2015 2015-06-09           14
# 1          2015   228436354      5  13  2015 2015-05-13           18
# 2          2015   185238201      3  18  2015 2015-03-18            9
# 3          2015  1868178225     12  15  2015 2015-12-15           28
# 4          2015  1316249360      4   1  2015 2015-04-01            9
#
#    num_words
# 0         26
# 1        110
# 2         22
# 3         26
# 4         14
#
# [5 rows x 21 columns]

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# в словарь вставляем номер вопроса и ваш ответ на него
# Пример: 
# answers['1'] = '2. Spider-Man 3 (tt0413300)'
# запишите свой вариант ответа
answers['1'] = '5. Pirates of the Caribbean: On Stranger Tides (tt1298650) +'
# если ответили верно, можете добавить комментарий со значком "+"

# %%
# тут пишем ваш код для решения данного вопроса:
data.loc[data.budget == data.budget.max()]
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  ... release_date vote_average  release_year  \
# 723  Adventure|Action|Fantasy  ...    5/11/2011          6.3          2011
#
#         profit  month day  year   timefunc title_length  num_words
# 723  641683000      5  11  2011 2011-05-11           43         75
#
# [1 rows x 21 columns]

# %% [markdown]
# ВАРИАНТ 2

# %%
data.sort_values(by = ['budget'], ascending=False).head(1)
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  ... release_date vote_average  release_year  \
# 723  Adventure|Action|Fantasy  ...    5/11/2011          6.3          2011
#
#         profit  month day  year   timefunc title_length  num_words
# 723  641683000      5  11  2011 2011-05-11           43         75
#
# [1 rows x 21 columns]

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
# думаю логику работы с этим словарем вы уже поняли, 
# по этому не буду больше его дублировать
answers['2'] = '2. Gods and Generals (tt0279111) +'

# %%
data.loc[data.runtime == data.runtime.max()]
# Out:
#         imdb_id    budget   revenue     original_title  \
# 1157  tt0279111  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1157  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1157  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1157  The film centers mostly around the personal an...      214
#
#                  genres  ... release_date vote_average  release_year  \
# 1157  Drama|History|War  ...    2/21/2003          5.8          2003
#
#         profit  month day  year   timefunc title_length  num_words
# 1157 -43076064      2  21  2003 2003-02-21           17         48
#
# [1 rows x 21 columns]

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
data.loc[data.runtime == data.runtime.min()]
# Out:
#        imdb_id    budget   revenue   original_title  \
# 768  tt1449283  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 768  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 768  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 768  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres  ... release_date vote_average  release_year    profit  \
# 768  Animation|Family  ...    4/13/2011          6.8          2011 -15540000
#
#      month day  year   timefunc title_length  num_words
# 768      4  13  2011 2011-04-13           15         52
#
# [1 rows x 21 columns]

# %%
answers['3'] = '3. Winnie the Pooh (tt1449283) +'

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
round(data.runtime.mean())
# Out:
# 110

# %%
data.describe().runtime['mean']
# Out:
# 109.6585494970884

# %%
answers['4'] = '2. 110 +'

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
round(data.runtime.median())
# Out:
# 107

# %%
data.describe().runtime['50%']
# Out:
# 107.0

# %%
answers['5'] = '1. 107 +'
answers
# Out:
# {'1': '5. Pirates of the Caribbean: On Stranger Tides (tt1298650) +',
#  '2': '2. Gods and Generals (tt0279111) +',
#  '3': '3. Winnie the Pooh (tt1449283) +',
#  '4': '2. 110 +',
#  '5': '1. 107 +'}

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
# лучше код получения столбца profit вынести в Предобработку что в начале
data.loc[data.profit == data.profit.max()]
# Out:
#        imdb_id     budget     revenue original_title  \
# 239  tt0499549  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  ... release_date vote_average  \
# 239  Action|Adventure|Fantasy|Science Fiction  ...   12/10/2009          7.1
#
#      release_year      profit  month day  year   timefunc title_length  \
# 239          2009  2544505847     12  10  2009 2009-12-10            6
#
#      num_words
# 239         28
#
# [1 rows x 21 columns]

# %%
data.sort_values(by='profit', ascending=False).head(1)
# Out:
#        imdb_id     budget     revenue original_title  \
# 239  tt0499549  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  ... release_date vote_average  \
# 239  Action|Adventure|Fantasy|Science Fiction  ...   12/10/2009          7.1
#
#      release_year      profit  month day  year   timefunc title_length  \
# 239          2009  2544505847     12  10  2009 2009-12-10            6
#
#      num_words
# 239         28
#
# [1 rows x 21 columns]

# %%
answers['6'] = '5. Avatar (tt0499549) +'

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
data.sort_values(by='profit').head(1)
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  ... release_date vote_average  release_year  \
# 1245  Action|Adventure|Western  ...     7/3/2013          6.0          2013
#
#          profit  month day  year   timefunc title_length  num_words
# 1245 -165710090      7   3  2013 2013-07-03           15         68
#
# [1 rows x 21 columns]

# %%
data.loc[data.profit == data.profit.min()]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  ... release_date vote_average  release_year  \
# 1245  Action|Adventure|Western  ...     7/3/2013          6.0          2013
#
#          profit  month day  year   timefunc title_length  num_words
# 1245 -165710090      7   3  2013 2013-07-03           15         68
#
# [1 rows x 21 columns]

# %%
answers['7'] = '5. The Lone Ranger (tt1210819) +'

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
len(data[data.revenue > data.budget])
# Out:
# 1478

# %%
data[data.revenue > data.budget].describe() #count - is answer, also check of the filtered data
# Out:
#              budget       revenue      runtime  vote_average  release_year  \
# count  1.478000e+03  1.478000e+03  1478.000000   1478.000000   1478.000000
# mean   5.742285e+07  1.915854e+08   110.126522      6.240122   2008.039242
# std    5.170014e+07  2.295625e+08    18.288838      0.738106      4.479981
# min    5.000000e+06  8.203235e+06    72.000000      3.400000   2000.000000
# 25%    2.000000e+07  5.903202e+07    97.000000      5.800000   2004.000000
# 50%    4.000000e+07  1.130136e+08   107.000000      6.200000   2008.000000
# 75%    7.875000e+07  2.218417e+08   121.000000      6.700000   2012.000000
# max    3.800000e+08  2.781506e+09   201.000000      8.100000   2015.000000
#
#              profit  title_length    num_words
# count  1.478000e+03   1478.000000  1478.000000
# mean   1.341626e+08     15.292287    53.547361
# std    1.941708e+08      8.817403    26.862752
# min    2.000000e+06      1.000000    10.000000
# 25%    2.724810e+07      9.000000    34.000000
# 50%    6.709555e+07     13.000000    50.000000
# 75%    1.507748e+08     19.000000    67.000000
# max    2.544506e+09     83.000000   169.000000

# %%
answers['8'] = '1. 1478 +'

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
data.loc[(data.release_year == 2008)].sort_values(by='profit', ascending=False).head()
# Out:
#        imdb_id     budget     revenue  \
# 599  tt0468569  185000000  1001921825
# 603  tt0367882  185000000   786636033
# 607  tt0795421   52000000   609841637
# 606  tt0441773  130000000   631744560
# 621  tt0448157  150000000   624029371
#
#                                         original_title  \
# 599                                    The Dark Knight
# 603  Indiana Jones and the Kingdom of the Crystal S...
# 607                                         Mamma Mia!
# 606                                      Kung Fu Panda
# 621                                            Hancock
#
#                                                   cast  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...
# 603  Harrison Ford|Cate Blanchett|Shia LaBeouf|Ray ...
# 607  Meryl Streep|Pierce Brosnan|Amanda Seyfried|Co...
# 606  Jack Black|Dustin Hoffman|Angelina Jolie|Jacki...
# 621  Will Smith|Charlize Theron|Jason Bateman|Jae H...
#
#                         director  \
# 599            Christopher Nolan
# 603             Steven Spielberg
# 607               Phyllida Lloyd
# 606  Mark Osborne|John Stevenson
# 621                   Peter Berg
#
#                                             tagline  \
# 599                                 Why So Serious?
# 603                   The adventure continues . . .
# 607  Take a trip down the aisle you'll never forget
# 606                        Prepare for awesomeness.
# 621          Bad Behavior. Bad Attitude. Real Hero.
#
#                                               overview  runtime  \
# 599  Batman raises the stakes in his war on crime. ...      152
# 603  Set during the Cold War, the Soviets â€“ led b...      122
# 607  Set on an idyllic Greek island, the plot serve...      108
# 606  When the Valley of Peace is threatened, lazy P...       90
# 621  Hancock is a down-and-out superhero who's forc...       92
#
#                           genres  ... release_date vote_average  release_year  \
# 599  Drama|Action|Crime|Thriller  ...    7/16/2008          8.1          2008
# 603             Adventure|Action  ...    5/21/2008          5.6          2008
# 607               Comedy|Romance  ...    6/30/2008          6.2          2008
# 606             Animation|Family  ...     6/4/2008          6.8          2008
# 621               Fantasy|Action  ...     7/1/2008          6.0          2008
#
#         profit  month day  year   timefunc title_length  num_words
# 599  816921825      7  16  2008 2008-07-16           15         67
# 603  601636033      5  21  2008 2008-05-21           50         74
# 607  557841637      6  30  2008 2008-06-30           10         63
# 606  501744560      6   4  2008 2008-06-04           13         60
# 621  474029371      7   1  2008 2008-07-01            7         63
#
# [5 rows x 21 columns]

# %%
data2008 = data.loc[(data.release_year == 2008)] # new df for films released in 2008
data2008.loc[(data2008.profit == data2008.profit.max())] # - answer
# Out:
#        imdb_id     budget     revenue   original_title  \
# 599  tt0468569  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 599  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  ... release_date vote_average  \
# 599      152  Drama|Action|Crime|Thriller  ...    7/16/2008          8.1
#
#      release_year     profit  month day  year   timefunc title_length  \
# 599          2008  816921825      7  16  2008 2008-07-16           15
#
#      num_words
# 599         67
#
# [1 rows x 21 columns]

# %%
answers['9'] = '4. The Dark Knight (tt0468569) +'

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
data[(data.release_year >= 2012) & (data.release_year <= 2014)].sort_values(by='profit').head(1)
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  ... release_date vote_average  release_year  \
# 1245  Action|Adventure|Western  ...     7/3/2013          6.0          2013
#
#          profit  month day  year   timefunc title_length  num_words
# 1245 -165710090      7   3  2013 2013-07-03           15         68
#
# [1 rows x 21 columns]

# %%
answers['10'] = '5. The Lone Ranger (tt1210819) +'

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
# эту задачу тоже можно решать разными подходами, попробуй реализовать разные варианты
# если будешь добавлять функцию - выноси ее в предобработку что в начале
pd.Series(data['genres'].str.cat(sep='|').split('|')).value_counts()
# Out:
# Drama              782
# Comedy             683
# Thriller           596
# Action             582
# Adventure          415
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            222
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             19
# Documentary          8
# Foreign              2
# dtype: int64

# %%
answers['11'] = '3. Drama +'

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
profit_df = data[data.profit>0].copy()
pd.Series(profit_df['genres'].str.cat(sep='|').split('|')).value_counts()
# Out:
# Drama              560
# Comedy             551
# Thriller           446
# Action             444
# Adventure          337
# Romance            242
# Crime              231
# Family             226
# Science Fiction    195
# Fantasy            188
# Horror             150
# Animation          120
# Mystery            119
# Music               47
# History             46
# War                 41
# Western             12
# Documentary          7
# dtype: int64

# %%
answers['12'] = '1. Drama +'

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сборы?

# %%
data.pivot_table(values = 'revenue', index = 'director', aggfunc='sum').sort_values(by='revenue',ascending=False)
# Profit is not splited between the directorsof the single movie
# Out:
#                       revenue
# director
# Peter Jackson      6490593685
# Christopher Nolan  4167548502
# David Yates        4154295625
# Michael Bay        3886938960
# J.J. Abrams        3579169916
# ...                       ...
# David MichÃ´d         2295423
# Steven Shainberg      2281089
# Paul Schrader         2062066
# Keanu Reeves          2054941
# Simon Hunter          2033165
#
# [957 rows x 1 columns]

# %%
answers['13'] = '5. Peter Jackson +'

# %%
#Example from Slack
# for director in directors.index:
#     directors[director] = data['revenue'][data['director'].map(lambda x: True if director in x else False)].sum()
# directors.sort_values(ascending=False)
# Profit is not splitted between the directorsof the single movie

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
action_df = data[data.genres.str.contains('Action')].copy() # data sorted for Action genres
pd.Series(action_df['director'].str.cat(sep='|').split('|')).value_counts() #Directors separated and counted
# Out:
# Robert Rodriguez      9
# Paul W.S. Anderson    7
# Michael Bay           7
# Antoine Fuqua         6
# Ridley Scott          6
#                      ..
# Steven Quale          1
# Daniel Espinosa       1
# Patrick Tatopoulos    1
# Sean McNamara         1
# John Herzfeld         1
# Length: 364, dtype: int64

# %%
answers['14'] = '3. Robert Rodriguez +'

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
artist_df = data[data.release_year == 2012].copy() #DF for filns released in 2012
artist_df['cast'] = artist_df.cast.str.split('|')
artist_df.explode('cast').pivot_table(values='revenue', index='cast', aggfunc='sum').sort_values(by='revenue',ascending=False)
# Out:
#                       revenue
# cast
# Chris Hemsworth    2027450773
# Denis Leary        1629460639
# Anne Hathaway      1522851057
# Robert Downey Jr.  1519557910
# Mark Ruffalo       1519557910
# ...                       ...
# Michael Nyqvist       3428048
# Danny Huston          2106557
# Josh Lucas            2106557
# Sami Gayle            2106557
# Nicolas Cage          2106557
#
# [466 rows x 1 columns]

# %%
answers['15'] = '3. Chris Hemsworth +'

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
budget_df = data.loc[data.budget > data.budget.mean()].copy() # New DF for movies with budget > mean budget. (for big data is not usefull)
budget_df['cast'] = budget_df.cast.str.split('|') # Split of the cast into the list
budget_df.explode('cast').value_counts('cast') # adding lines for each artist and counting
# Out:
# cast
# Matt Damon           18
# Adam Sandler         17
# Angelina Jolie       16
# Eddie Murphy         15
# Samuel L. Jackson    15
#                      ..
# Leslie Bibb           1
# Leonard Nimoy         1
# Lennie James          1
# Lena Olin             1
# 50 Cent               1
# Length: 1505, dtype: int64

# %%
pd.Series(data[data.budget > data.budget.mean()].cast.str.split('|').sum()).value_counts()
# 1) filter data to find movies with big budget
# 2) split data in the cast column into the lists
# 3) Adding all lists in cast column into the one
# 4) Count each unique element in the list
# Out:
# Matt Damon            18
# Adam Sandler          17
# Angelina Jolie        16
# Tom Cruise            15
# Eddie Murphy          15
#                       ..
# Cole Konis             1
# Edward James Olmos     1
# Ed Speleers            1
# Matthew Lillard        1
# Peter Sohn             1
# Length: 1505, dtype: int64

# %%
answers['16'] = '3. Matt Damon +'

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
Nicolas_Cage_df = data[data.cast.str.contains('Nicolas Cage')] # filtered dataframe for films with Nikolas Cage
pd.Series(Nicolas_Cage_df['genres'].str.cat(sep='|').split('|')).value_counts()
# Out:
# Action             17
# Thriller           15
# Drama              12
# Crime              10
# Fantasy             8
# Adventure           7
# Comedy              6
# Science Fiction     4
# Family              3
# Animation           3
# Mystery             3
# History             2
# Romance             1
# Horror              1
# War                 1
# dtype: int64

# %%
answers['17'] = '2. Action +'
answers
# Out:
# {'1': '5. Pirates of the Caribbean: On Stranger Tides (tt1298650) +',
#  '2': '2. Gods and Generals (tt0279111) +',
#  '3': '3. Winnie the Pooh (tt1449283) +',
#  '4': '2. 110 +',
#  '5': '1. 107 +',
#  '6': '5. Avatar (tt0499549) +',
#  '7': '5. The Lone Ranger (tt1210819) +',
#  '8': '1. 1478 +',
#  '9': '4. The Dark Knight (tt0468569) +',
#  '10': '5. The Lone Ranger (tt1210819) +',
#  '11': '3. Drama +',
#  '12': '1. Drama +',
#  '13': '5. Peter Jackson +',
#  '14': '3. Robert Rodriguez +',
#  '15': '3. Chris Hemsworth +',
#  '16': '3. Matt Damon +',
#  '17': '2. Action +'}

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
data[data.production_companies.str.contains('Paramount')].sort_values(by='profit').head(1)
# Out:
#        imdb_id     budget   revenue        original_title  \
# 925  tt0267626  100000000  35168966  K-19: The Widowmaker
#
#                                                   cast         director  \
# 925  Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...  Kathryn Bigelow
#
#                       tagline  \
# 925  Fate has found its hero.
#
#                                               overview  runtime  \
# 925  When Russia's first nuclear submarine malfunct...      138
#
#                      genres  ... release_date vote_average  release_year  \
# 925  Thriller|Drama|History  ...    7/19/2002          6.0          2002
#
#        profit  month day  year   timefunc title_length  num_words
# 925 -64831034      7  19  2002 2002-07-19           20         23
#
# [1 rows x 21 columns]

# %%
answers['18'] = '1. K-19: The Widowmaker (tt0267626)'

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
data.groupby(by='release_year').sum().sort_values(by='revenue',ascending=False).head(1)
# Out:
#                   budget      revenue  runtime  vote_average       profit  \
# release_year
# 2015          6780630004  25449202382    13355         755.2  18668572378
#
#               title_length  num_words
# release_year
# 2015                  1601       5524

# %%
data.pivot_table(index ='release_year', aggfunc='sum').sort_values(by='revenue').tail(1)
# Out:
#                   budget  num_words       profit      revenue  runtime  \
# release_year
# 2015          6780630004       5524  18668572378  25449202382    13355
#
#               title_length  vote_average
# release_year
# 2015                  1601         755.2

# %%
answers['19'] = '5. 2015 +'

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
WB_df=data[data.production_companies.str.contains('Warner')]
WB_df.pivot_table(index ='release_year', aggfunc='sum').sort_values(by='profit').tail(1)
# Out:
#                  budget  num_words      profit     revenue  runtime  \
# release_year
# 2014          947600000        672  2295464519  3243064519     1576
#
#               title_length  vote_average
# release_year
# 2014                   176          88.9

# %%
answers['20'] = '1. 2014 +'

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
data.pivot_table(values='original_title', index='month',aggfunc='count').sort_values(by='original_title')
# Out:
#        original_title
# month
# 1                 110
# 2                 135
# 5                 140
# 7                 142
# 11                146
# 6                 147
# 4                 149
# 3                 156
# 8                 161
# 10                186
# 12                190
# 9                 227

# %%
##Solution usith method .month()
data.groupby(by=data['timefunc'].dt.month).count().sort_values(by = 'original_title')
# Out:
#           imdb_id  budget  revenue  original_title  cast  director  tagline  \
# timefunc
# 1             110     110      110             110   110       110      110
# 2             135     135      135             135   135       135      135
# 5             140     140      140             140   140       140      140
# 7             142     142      142             142   142       142      142
# 11            146     146      146             146   146       146      146
# 6             147     147      147             147   147       147      147
# 4             149     149      149             149   149       149      149
# 3             156     156      156             156   156       156      156
# 8             161     161      161             161   161       161      161
# 10            186     186      186             186   186       186      186
# 12            190     190      190             190   190       190      190
# 9             227     227      227             227   227       227      227
#
#           overview  runtime  genres  ...  release_date  vote_average  \
# timefunc                             ...
# 1              110      110     110  ...           110           110
# 2              135      135     135  ...           135           135
# 5              140      140     140  ...           140           140
# 7              142      142     142  ...           142           142
# 11             146      146     146  ...           146           146
# 6              147      147     147  ...           147           147
# 4              149      149     149  ...           149           149
# 3              156      156     156  ...           156           156
# 8              161      161     161  ...           161           161
# 10             186      186     186  ...           186           186
# 12             190      190     190  ...           190           190
# 9              227      227     227  ...           227           227
#
#           release_year  profit  month  day  year  timefunc  title_length  \
# timefunc
# 1                  110     110    110  110   110       110           110
# 2                  135     135    135  135   135       135           135
# 5                  140     140    140  140   140       140           140
# 7                  142     142    142  142   142       142           142
# 11                 146     146    146  146   146       146           146
# 6                  147     147    147  147   147       147           147
# 4                  149     149    149  149   149       149           149
# 3                  156     156    156  156   156       156           156
# 8                  161     161    161  161   161       161           161
# 10                 186     186    186  186   186       186           186
# 12                 190     190    190  190   190       190           190
# 9                  227     227    227  227   227       227           227
#
#           num_words
# timefunc
# 1               110
# 2               135
# 5               140
# 7               142
# 11              146
# 6               147
# 4               149
# 3               156
# 8               161
# 10              186
# 12              190
# 9               227
#
# [12 rows x 21 columns]

# %%
answers['21'] = '4. Сентябрь +'

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
data.loc[data['timefunc'].dt.month.isin(['6','7','8'])].count()
# Out:
# imdb_id                 450
# budget                  450
# revenue                 450
# original_title          450
# cast                    450
# director                450
# tagline                 450
# overview                450
# runtime                 450
# genres                  450
# production_companies    450
# release_date            450
# vote_average            450
# release_year            450
# profit                  450
# month                   450
# day                     450
# year                    450
# timefunc                450
# title_length            450
# num_words               450
# dtype: int64

# %%
answers['22'] = '2. 450 +'

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
data[data['timefunc'].dt.month.isin(['12','1','2'])].director.str.split('|').value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1709, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Peter Jackson]                       7
# [Clint Eastwood]                      6
# [Steven Soderbergh]                   6
# [Shawn Levy]                          4
# [Nancy Meyers]                        4
#                                      ..
# [Paul Tibbitt]                        1
# [Florian Henckel von Donnersmarck]    1
# [Niki Caro]                           1
# [Mikael HÃ¥fstrÃ¶m]                   1
# [Guy Ferland]                         1
# Name: director, Length: 332, dtype: int64

# %%
answers['23'] = '5. Peter Jackson +'

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
pd_df = data.copy()
pd_df['production_companies'] = pd_df.production_companies.str.split('|')
pd_df.explode('production_companies').groupby(['production_companies'])['title_length'].agg(['mean']).sort_values(by = 'mean')
# Out:
#                             mean
# production_companies
# Global Entertainment Group   2.0
# Ixtlan Productions           2.0
# XM2 Productions              2.0
# Berlanti Productions         3.0
# Everest Entertainment        3.0
# ...                          ...
# Polsky Films                46.0
# Museum Canada Productions   46.0
# Dos Corazones               47.0
# Jim Henson Company, The     59.0
# Four By Two Productions     83.0
#
# [1771 rows x 1 columns]

# %%
answers['24'] = '5. Four By Two Productions +'

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
pd_df.explode('production_companies').groupby(['production_companies'])['num_words'].agg(['mean', 'max']).sort_values(by = 'mean')
# Out:
#                                         mean  max
# production_companies
# Motion Picture Corporation of America   11.0   11
# Empire Pictures                         11.0   11
# Henceforth                              13.0   13
# Phantom Four                            13.0   13
# London Boulevard                        13.0   13
# ...                                      ...  ...
# Brookwell-McNamara Entertainment       156.0  156
# 98 MPH Productions                     159.0  159
# Heineken Branded Entertainment         161.0  161
# Room 9 Entertainment                   161.0  161
# Midnight Picture Show                  175.0  175
#
# [1771 rows x 2 columns]

# %%
answers['25'] = '3. Midnight Picture Show +'

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
a = data.vote_average.quantile([0.99])#quantille method to get vote_average for 99% of the films

a[0.99]# 99% of the films has rating <= 7.8, or 1% of the best in rating > 7.8
# Out:
# 7.8

# %%
data.original_title[(data.vote_average >= a[0.99])] 
#Series of films with rating >= 7.8 (slightly more than 1%, as there are several films rated 7.8)
# Out:
# 9                                              Inside Out
# 28                                              Spotlight
# 34                                                   Room
# 118                                          Interstellar
# 119                               Guardians of the Galaxy
# 124                                            Big Hero 6
# 125                                    The Imitation Game
# 128                                             Gone Girl
# 138                              The Grand Budapest Hotel
# 155                              The Theory of Everything
# 177                                The Fault in Our Stars
# 283                                            Mr. Nobody
# 316                                              3 Idiots
# 370                                             Inception
# 496     The Lord of the Rings: The Fellowship of the Ring
# 599                                       The Dark Knight
# 863                 The Lord of the Rings: The Two Towers
# 872                                           The Pianist
# 1081        The Lord of the Rings: The Return of the King
# 1183                              The Wolf of Wall Street
# 1188                                                  Her
# 1191                                     12 Years a Slave
# 1205                                            Prisoners
# 1213                                   Dallas Buyers Club
# 1444                                         The Prestige
# 1563                Eternal Sunshine of the Spotless Mind
# 1688                                  There Will Be Blood
# 1800                                              Memento
# Name: original_title, dtype: object

# %%
data.sort_values(by='vote_average', ascending = False).head(18)
# Out:
#         imdb_id     budget     revenue  \
# 599   tt0468569  185000000  1001921825
# 118   tt0816692  165000000   621752480
# 125   tt2084970   14000000   233555708
# 9     tt2096673  175000000   853708609
# 34    tt3170832    6000000    35401758
# 1183  tt0993846  100000000   392000694
# 128   tt2267998   61000000   369330363
# 1191  tt2024544   20000000   187000000
# 119   tt2015381  170000000   773312399
# 1081  tt0167260   94000000  1118888979
# 1800  tt0209144    9000000    39723096
# 370   tt1375666  160000000   825500000
# 872   tt0253474   35000000   120072577
# 138   tt2278388   30000000   174600318
# 1188  tt1798709   23000000    47351251
# 28    tt1895587   20000000    88346473
# 124   tt2245084  165000000   652105443
# 177   tt2582846   12000000   305151265
#
#                                      original_title  \
# 599                                 The Dark Knight
# 118                                    Interstellar
# 125                              The Imitation Game
# 9                                        Inside Out
# 34                                             Room
# 1183                        The Wolf of Wall Street
# 128                                       Gone Girl
# 1191                               12 Years a Slave
# 119                         Guardians of the Galaxy
# 1081  The Lord of the Rings: The Return of the King
# 1800                                        Memento
# 370                                       Inception
# 872                                     The Pianist
# 138                        The Grand Budapest Hotel
# 1188                                            Her
# 28                                        Spotlight
# 124                                      Big Hero 6
# 177                          The Fault in Our Stars
#
#                                                    cast  \
# 599   Christian Bale|Michael Caine|Heath Ledger|Aaro...
# 118   Matthew McConaughey|Jessica Chastain|Anne Hath...
# 125   Benedict Cumberbatch|Keira Knightley|Matthew G...
# 9     Amy Poehler|Phyllis Smith|Richard Kind|Bill Ha...
# 34    Brie Larson|Jacob Tremblay|Joan Allen|Sean Bri...
# 1183  Leonardo DiCaprio|Jonah Hill|Margot Robbie|Kyl...
# 128   Ben Affleck|Rosamund Pike|Carrie Coon|Neil Pat...
# 1191  Chiwetel Ejiofor|Michael Fassbender|Lupita Nyo...
# 119   Chris Pratt|Zoe Saldana|Dave Bautista|Vin Dies...
# 1081  Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...
# 1800  Guy Pearce|Carrie-Anne Moss|Joe Pantoliano|Mar...
# 370   Leonardo DiCaprio|Joseph Gordon-Levitt|Ellen P...
# 872   Adrien Brody|Thomas Kretschmann|Frank Finlay|M...
# 138   Ralph Fiennes|Tony Revolori|F. Murray Abraham|...
# 1188  Joaquin Phoenix|Scarlett Johansson|Rooney Mara...
# 28    Mark Ruffalo|Michael Keaton|Rachel McAdams|Lie...
# 124   Scott Adsit|Ryan Potter|Daniel Henney|T.J. Mil...
# 177   Shailene Woodley|Ansel Elgort|Nat Wolff|Laura ...
#
#                      director  \
# 599         Christopher Nolan
# 118         Christopher Nolan
# 125             Morten Tyldum
# 9                 Pete Docter
# 34           Lenny Abrahamson
# 1183          Martin Scorsese
# 128             David Fincher
# 1191            Steve McQueen
# 119                James Gunn
# 1081            Peter Jackson
# 1800        Christopher Nolan
# 370         Christopher Nolan
# 872            Roman Polanski
# 138              Wes Anderson
# 1188              Spike Jonze
# 28               Tom McCarthy
# 124   Don Hall|Chris Williams
# 177                Josh Boone
#
#                                                 tagline  \
# 599                                     Why So Serious?
# 118   Mankind was born on Earth. It was never meant ...
# 125   The true enigma was the man who cracked the code.
# 9              Meet the little voices inside your head.
# 34                             Love knows no boundaries
# 1183                                EARN. SPEND. PARTY.
# 128         You don't know what you've got 'til it's...
# 1191    The extraordinary true story of Solomon Northup
# 119                         All heroes start somewhere.
# 1081                    The eye of the enemy is moving.
# 1800                  Some memories are best forgotten.
# 370                Your mind is the scene of the crime.
# 872   Music was his passion. Survival was his master...
# 138             A perfect holiday without leaving home.
# 1188                           A Spike Jonze Love Story
# 28                  Break the story. Break the silence.
# 124      From the creators of Wreck-it Ralph and Frozen
# 177                                 One Sick Love Story
#
#                                                overview  runtime  \
# 599   Batman raises the stakes in his war on crime. ...      152
# 118   Interstellar chronicles the adventures of a gr...      169
# 125   Based on the real life story of legendary cryp...      113
# 9     Growing up can be a bumpy road, and it's no ex...       94
# 34    Jack is a young boy of 5 years old who has liv...      117
# 1183  A New York stockbroker refuses to cooperate in...      180
# 128   With his wife's disappearance having become th...      145
# 1191  In the pre-Civil War United States, Solomon No...      134
# 119   Light years from Earth, 26 years after being a...      121
# 1081  Aragorn is revealed as the heir to the ancient...      201
# 1800  Suffering short-term memory loss after a head ...      113
# 370   Cobb, a skilled thief who commits corporate es...      148
# 872   The Pianist is a film adapted from the biograp...      150
# 138   The Grand Budapest Hotel tells of a legendary ...       99
# 1188  In the not so distant future, Theodore, a lone...      126
# 28    The true story of how The Boston Globe uncover...      128
# 124   The special bond that develops between plus-si...      102
# 177   Despite the tumor-shrinking medical miracle th...      125
#
#                                                  genres  ... release_date  \
# 599                         Drama|Action|Crime|Thriller  ...    7/16/2008
# 118                     Adventure|Drama|Science Fiction  ...    11/5/2014
# 125                          History|Drama|Thriller|War  ...   11/14/2014
# 9                               Comedy|Animation|Family  ...     6/9/2015
# 34                                       Drama|Thriller  ...   10/16/2015
# 1183                                 Crime|Drama|Comedy  ...   12/25/2013
# 128                              Mystery|Thriller|Drama  ...    10/1/2014
# 1191                                      Drama|History  ...   10/18/2013
# 119                    Action|Science Fiction|Adventure  ...    7/30/2014
# 1081                           Adventure|Fantasy|Action  ...    12/1/2003
# 1800                                   Mystery|Thriller  ...   10/11/2000
# 370   Action|Thriller|Science Fiction|Mystery|Adventure  ...    7/14/2010
# 872                                           Drama|War  ...    9/24/2002
# 138                                        Comedy|Drama  ...    2/26/2014
# 1188                      Romance|Science Fiction|Drama  ...   12/18/2013
# 28                               Drama|Thriller|History  ...    11/6/2015
# 124            Adventure|Family|Animation|Action|Comedy  ...   10/24/2014
# 177                                       Romance|Drama  ...    5/16/2014
#
#      vote_average  release_year      profit  month day  year   timefunc  \
# 599           8.1          2008   816921825      7  16  2008 2008-07-16
# 118           8.0          2014   456752480     11   5  2014 2014-11-05
# 125           8.0          2014   219555708     11  14  2014 2014-11-14
# 9             8.0          2015   678708609      6   9  2015 2015-06-09
# 34            8.0          2015    29401758     10  16  2015 2015-10-16
# 1183          7.9          2013   292000694     12  25  2013 2013-12-25
# 128           7.9          2014   308330363     10   1  2014 2014-10-01
# 1191          7.9          2013   167000000     10  18  2013 2013-10-18
# 119           7.9          2014   603312399      7  30  2014 2014-07-30
# 1081          7.9          2003  1024888979     12   1  2003 2003-12-01
# 1800          7.9          2000    30723096     10  11  2000 2000-10-11
# 370           7.9          2010   665500000      7  14  2010 2010-07-14
# 872           7.9          2002    85072577      9  24  2002 2002-09-24
# 138           7.9          2014   144600318      2  26  2014 2014-02-26
# 1188          7.8          2013    24351251     12  18  2013 2013-12-18
# 28            7.8          2015    68346473     11   6  2015 2015-11-06
# 124           7.8          2014   487105443     10  24  2014 2014-10-24
# 177           7.8          2014   293151265      5  16  2014 2014-05-16
#
#      title_length  num_words
# 599            15         67
# 118            12         35
# 125            18         46
# 9              10        112
# 34              4         49
# 1183           23         29
# 128             9         30
# 1191           16         61
# 119            23         28
# 1081           45         45
# 1800            7         78
# 370             9         44
# 872            11         39
# 138            24         66
# 1188            3         65
# 28              9         30
# 124            10         29
# 177            22         47
#
# [18 rows x 21 columns]

# %%
answers['26'] = '1. Inside Out, The Dark Knight, 12 Years a Slave +'

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %%
data['cast'] = data.cast.apply(func) # Used function to split cast column to list
data['cast_comb'] = data.cast.apply(func_comb) # New column in dataset with combination of the artist pairs
data.explode('cast_comb').value_counts('cast_comb') #Data DF exploded to use .value_counts().
# Out:
# cast_comb
# (Daniel Radcliffe, Emma Watson)             8
# (Daniel Radcliffe, Rupert Grint)            8
# (Rupert Grint, Emma Watson)                 7
# (Ben Stiller, Owen Wilson)                  6
# (Johnny Depp, Helena Bonham Carter)         6
#                                            ..
# (Matthew McConaughey, Rene Russo)           1
# (Matthew McConaughey, Reese Witherspoon)    1
# (Matthew McConaughey, Powers Boothe)        1
# (Matthew McConaughey, PenÃ©lope Cruz)       1
# (50 Cent, Adewale Akinnuoye-Agbaje)         1
# Length: 18121, dtype: int64

# %%
answers['27'] = '5. Daniel Radcliffe & Rupert Grint +'

# %% [markdown]
# ВАРИАНТ 2

# %%
list_of_pairs = []
import collections
c = collections.Counter() #Counter created

for elem in data['cast_comb'].tolist(): #cycle to go thru the list of pairs and add to the single list
    for pair in elem:
        list_of_pairs.append(pair)
for pair in list_of_pairs: #cycle to count the elements in the list
    c[pair] += 1
print(c.most_common()[0:3]) #printed first 3 of the most common pairs
# Out:
# [(('Daniel Radcliffe', 'Rupert Grint'), 8), (('Daniel Radcliffe', 'Emma Watson'), 8), (('Rupert Grint', 'Emma Watson'), 7)]

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': '5. Pirates of the Caribbean: On Stranger Tides (tt1298650) +',
#  '2': '2. Gods and Generals (tt0279111) +',
#  '3': '3. Winnie the Pooh (tt1449283) +',
#  '4': '2. 110 +',
#  '5': '1. 107 +',
#  '6': '5. Avatar (tt0499549) +',
#  '7': '5. The Lone Ranger (tt1210819) +',
#  '8': '1. 1478 +',
#  '9': '4. The Dark Knight (tt0468569) +',
#  '10': '5. The Lone Ranger (tt1210819) +',
#  '11': '3. Drama +',
#  '12': '1. Drama +',
#  '13': '5. Peter Jackson +',
#  '14': '3. Robert Rodriguez +',
#  '15': '3. Chris Hemsworth +',
#  '16': '3. Matt Damon +',
#  '17': '2. Action +',
#  '18': '1. K-19: The Widowmaker (tt0267626)',
#  '19': '5. 2015 +',
#  '20': '1. 2014 +',
#  '21': '4. Сентябрь +',
#  '22': '2. 450 +',
#  '23': '5. Peter Jackson +',
#  '24': '5. Four By Two Productions +',
#  '25': '3. Midnight Picture Show +',
#  '26': '1. Inside Out, The Dark Knight, 12 Years a Slave +',
#  '27': '5. Daniel Radcliffe & Rupert Grint +'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
# Out:
# 27
